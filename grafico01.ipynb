# %%
import matplotlib.pyplot as plt

# Generamos 20 puntos aleatorios
x = [1, 3, 6, 8, 9, 10, 12, 14, 15, 17, 18, 20, 22, 24, 25, 27, 28, 30, 32, 34]
y = [0.3, 0.5, 0.7, 0.9, 1.1, 1.3, 1.5, 1.7, 1.9, 2.1, 2.3, 2.5, 2.7, 2.9, 3.1, 3.3, 3.5, 3.7, 3.9, 4.1]

# Creamos el gráfico de dispersión
plt.scatter(x, y) 

# Mostrar gráfico
plt.show()
